# %%
# !git clone https://github.com/libindic/indic-trans.git
# Out:
# Cloning into 'indic-trans'...
# Updating files:  18% (136/719)
# Updating files:  19% (137/719)
# Updating files:  20% (144/719)
# Updating files:  21% (151/719)
# Updating files:  22% (159/719)
# Updating files:  23% (166/719)
# Updating files:  24% (173/719)
# Updating files:  25% (180/719)
# Updating files:  26% (187/719)
# Updating files:  27% (195/719)
# Updating files:  28% (202/719)
# Updating files:  29% (209/719)
# Updating files:  30% (216/719)
# Updating files:  31% (223/719)
# Updating files:  32% (231/719)
# Updating files:  33% (238/719)
# Updating files:  34% (245/719)
# Updating files:  35% (252/719)
# Updating files:  36% (259/719)
# Updating files:  37% (267/719)
# Updating files:  38% (274/719)
# Updating files:  39% (281/719)
# Updating files:  40% (288/719)
# Updating files:  41% (295/719)
# Updating files:  42% (302/719)
# Updating files:  42% (307/719)
# Updating files:  43% (310/719)
# Updating files:  44% (317/719)
# Updating files:  45% (324/719)
# Updating files:  46% (331/719)
# Updating files:  47% (338/719)
# Updating files:  48% (346/719)
# Updating files:  49% (353/719)
# Updating files:  50% (360/719)
# Updating files:  51% (367/719)
# Updating files:  52% (374/719)
# Updating files:  53% (382/719)
# Updating files:  54% (389/719)
# Updating files:  55% (396/719)
# Updating files:  56% (403/719)
# Updating files:  57% (410/719)
# Updating files:  58% (418/719)
# Updating files:  58% (423/719)
# Updating files:  59% (425/719)
# Updating files:  60% (432/719)
# Updating files:  61% (439/719)
# Updating files:  62% (446/719)
# Updating files:  63% (453/719)
# Updating files:  64% (461/719)
# Updating files:  65% (468/719)
# Updating files:  66% (475/719)
# Updating files:  67% (482/719)
# Updating files:  68% (489/719)
# Updating files:  69% (497/719)
# Updating files:  70% (504/719)
# Updating files:  71% (511/719)
# Updating files:  72% (518/719)
# Updating files:  73% (525/719)
# Updating files:  74% (533/719)
# Updating files:  75% (540/719)
# Updating files:  76% (547/719)
# Updating files:  76% (549/719)
# Updating files:  77% (554/719)
# Updating files:  78% (561/719)
# Updating files:  79% (569/719)
# Updating files:  80% (576/719)
# Updating files:  81% (583/719)
# Updating files:  82% (590/719)
# Updating files:  83% (597/719)
# Updating files:  84% (604/719)
# Updating files:  85% (612/719)
# Updating files:  86% (619/719)
# Updating files:  87% (626/719)
# Updating files:  88% (633/719)
# Updating files:  89% (640/719)
# Updating files:  90% (648/719)
# Updating files:  90% (651/719)
# Updating files:  91% (655/719)
# Updating files:  92% (662/719)
# Updating files:  93% (669/719)
# Updating files:  94% (676/719)
# Updating files:  95% (684/719)
# Updating files:  96% (691/719)
# Updating files:  97% (698/719)
# Updating files:  98% (705/719)
# Updating files:  99% (712/719)
# Updating files: 100% (719/719)
# Updating files: 100% (719/719), done.

# %%
# !pip install -r indic-trans/requirements.txt
# Out:
# Collecting pbr (from -r indic-trans/requirements.txt (line 1))
#   Obtaining dependency information for pbr from https://files.pythonhosted.org/packages/64/dd/171c9fb653591cf265bcc89c436eec75c9bde3dec921cc236fa71e5698df/pbr-6.0.0-py2.py3-none-any.whl.metadata
#   Downloading pbr-6.0.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: six in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from -r indic-trans/requirements.txt (line 2)) (1.16.0)
# Collecting future (from -r indic-trans/requirements.txt (line 3))
#   Obtaining dependency information for future from https://files.pythonhosted.org/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl.metadata
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cython>=0.24.0a0 (from -r indic-trans/requirements.txt (line 4))
#   Obtaining dependency information for cython>=0.24.0a0 from https://files.pythonhosted.org/packages/18/ec/f47a721071d084d6c2b6783eb8d058b964b1450cb708d920d0d792f42001/Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata
#   Using cached Cython-3.0.10-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from -r indic-trans/requirements.txt (line 5)) (1.25.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from -r indic-trans/requirements.txt (line 6)) (1.11.1)
# Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#    ---------------------------------------- 0.0/107.5 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/107.5 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 107.5/107.5 kB 1.6 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------- ------------------------ 184.3/491.3 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 5.1 MB/s eta 0:00:00
# Using cached Cython-3.0.10-cp311-cp311-win_amd64.whl (2.8 MB)
# Installing collected packages: pbr, future, cython
# Successfully installed cython-3.0.10 future-1.0.0 pbr-6.0.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install indic-trans/.
# Out:
# Processing d:\koding\codes\machine learning\ictc\notebooks\indic-trans
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pbr in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (6.0.0)
# Requirement already satisfied: six in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.16.0)
# Requirement already satisfied: future in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.0.0)
# Requirement already satisfied: cython>=0.24.0a0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (3.0.10)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.25.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.11.1)
# Building wheels for collected packages: indictrans
#   Building wheel for indictrans (pyproject.toml): started
#   Building wheel for indictrans (pyproject.toml): finished with status 'error'
# Failed to build indictrans
#   error: subprocess-exited-with-error
#
#   × Building wheel for indictrans (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1219 lines of output]
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
#       !!
#
#               ********************************************************************************
#               Please avoid running ``setup.py`` and ``easy_install``.
#               Instead, use pypa/build, pypa/installer or other
#               standards-based tools.
#
#               See https://github.com/pypa/setuptools/issues/917 for details.
#               ********************************************************************************
#
#       !!
#         easy_install.initialize_options(self)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'author-email' will not be supported in future
#               versions. Please use the underscore name 'author_email' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'home-page' will not be supported in future
#               versions. Please use the underscore name 'home_page' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       The [wheel] section is deprecated. Use [bdist_wheel] instead.
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\indictrans
#       creating build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\test_trans.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\base.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\script_transliterate.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\transliterator.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\__init__.py -> build\lib.win-amd64-cpython-311\indictrans
#       creating build\lib.win-amd64-cpython-311\indictrans\trunk
#       creating build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\test_trunk.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\perceptron.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       creating build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       creating build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\one_hot_encoder.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\script_normalizer.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\wx.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       running egg_info
#       creating indictrans.egg-info
#       writing indictrans.egg-info\PKG-INFO
#       writing dependency_links to indictrans.egg-info\dependency_links.txt
#       writing entry points to indictrans.egg-info\entry_points.txt
#       writing requirements to indictrans.egg-info\requires.txt
#       writing top-level names to indictrans.egg-info\top_level.txt
#       writing pbr to indictrans.egg-info\pbr.json
#       [pbr] Processing SOURCES.txt
#       writing manifest file 'indictrans.egg-info\SOURCES.txt'
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       [pbr] In git context, generating filelist from git
#       warning: no files found matching 'AUTHORS'
#       warning: no files found matching 'ChangeLog'
#       warning: no previously-included files found matching '.gitreview'
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       adding license file 'LICENSE'
#       writing manifest file 'indictrans.egg-info\SOURCES.txt'
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans._decode' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans._decode' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans._decode' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans._decode' to be distributed and are
#               already explicitly excluding 'indictrans._decode' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans._utils' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans._utils' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans._utils' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans._utils' to be distributed and are
#               already explicitly excluding 'indictrans._utils' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.mappings' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.mappings' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.mappings' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.mappings' to be distributed and are
#               already explicitly excluding 'indictrans.mappings' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.models' to be distributed and are
#               already explicitly excluding 'indictrans.models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.tests' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.tests' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.tests' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.tests' to be distributed and are
#               already explicitly excluding 'indictrans.tests' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.trunk' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.trunk' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.trunk' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.trunk' to be distributed and are
#               already explicitly excluding 'indictrans.trunk' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-4it5t1uy\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.trunk.tests' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.trunk.tests' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.trunk.tests' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.trunk.tests' to be distributed and are
#               already explicitly excluding 'indictrans.trunk.tests' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying indictrans\_decode\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\beamsearch.c -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\beamsearch.pyx -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\viterbi.c -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\viterbi.pyx -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_utils\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\ctranxn.c -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\ctranxn.pyx -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\one_hot_encoder.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\script_normalizer.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\sparseadd.c -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\sparseadd.pyx -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\wx.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       creating build\lib.win-amd64-cpython-311\indictrans\mappings
#       copying indictrans\mappings\punkt.map -> build\lib.win-amd64-cpython-311\indictrans\mappings
#       copying indictrans\mappings\urdu_urdu.map -> build\lib.win-amd64-cpython-311\indictrans\mappings
#       creating build\lib.win-amd64-cpython-311\indictrans\models
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       creating build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       creating build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       creating build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       creating build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       creating build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
# ...
#       copying indictrans\models\tel-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       creating build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       creating build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\ben_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\eng_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\guj_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\hin_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\hin_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\indic-test -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\kan_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\mal_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\ori_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\pan_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\pan_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\tam_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\tel_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\test_trans.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\trunk\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\perceptron.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\hin2rom.tnt -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\test_trunk.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       running build_ext
#       building 'indictrans._decode.beamsearch' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for indictrans
# ERROR: Could not build wheels for indictrans, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install indic-trans/
# Out:
# Processing d:\koding\codes\machine learning\ictc\notebooks\indic-trans
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pbr in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (6.0.0)
# Requirement already satisfied: six in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.16.0)
# Requirement already satisfied: future in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.0.0)
# Requirement already satisfied: cython>=0.24.0a0 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (3.0.10)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.25.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\agrvi\appdata\local\programs\python\python311\lib\site-packages (from indictrans==1.2.3) (1.11.1)
# Building wheels for collected packages: indictrans
#   Building wheel for indictrans (pyproject.toml): started
#   Building wheel for indictrans (pyproject.toml): finished with status 'error'
# Failed to build indictrans
#   error: subprocess-exited-with-error
#
#   × Building wheel for indictrans (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1097 lines of output]
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
#       !!
#
#               ********************************************************************************
#               Please avoid running ``setup.py`` and ``easy_install``.
#               Instead, use pypa/build, pypa/installer or other
#               standards-based tools.
#
#               See https://github.com/pypa/setuptools/issues/917 for details.
#               ********************************************************************************
#
#       !!
#         easy_install.initialize_options(self)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'author-email' will not be supported in future
#               versions. Please use the underscore name 'author_email' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\dist.py:476: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'home-page' will not be supported in future
#               versions. Please use the underscore name 'home_page' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       The [wheel] section is deprecated. Use [bdist_wheel] instead.
#       running build
#       running build_py
#       copying indictrans\base.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\script_transliterate.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\transliterator.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\__init__.py -> build\lib.win-amd64-cpython-311\indictrans
#       copying indictrans\trunk\perceptron.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\tests\test_trunk.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\_utils\one_hot_encoder.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\script_normalizer.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\wx.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_decode\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\tests\test_trans.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       running egg_info
#       writing indictrans.egg-info\PKG-INFO
#       writing dependency_links to indictrans.egg-info\dependency_links.txt
#       writing entry points to indictrans.egg-info\entry_points.txt
#       writing requirements to indictrans.egg-info\requires.txt
#       writing top-level names to indictrans.egg-info\top_level.txt
#       writing pbr to indictrans.egg-info\pbr.json
#       [pbr] Processing SOURCES.txt
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       [pbr] In git context, generating filelist from git
#       warning: no files found matching 'AUTHORS'
#       warning: no files found matching 'ChangeLog'
#       warning: no previously-included files found matching '.gitreview'
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       adding license file 'LICENSE'
#       writing manifest file 'indictrans.egg-info\SOURCES.txt'
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans._decode' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans._decode' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans._decode' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans._decode' to be distributed and are
#               already explicitly excluding 'indictrans._decode' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans._utils' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans._utils' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans._utils' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans._utils' to be distributed and are
#               already explicitly excluding 'indictrans._utils' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.mappings' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.mappings' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.mappings' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.mappings' to be distributed and are
#               already explicitly excluding 'indictrans.mappings' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.models' to be distributed and are
#               already explicitly excluding 'indictrans.models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.tests' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.tests' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.tests' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.tests' to be distributed and are
#               already explicitly excluding 'indictrans.tests' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.trunk' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.trunk' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.trunk' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.trunk' to be distributed and are
#               already explicitly excluding 'indictrans.trunk' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\agrvi\AppData\Local\Temp\pip-build-env-no79vlf1\overlay\Lib\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'indictrans.trunk.tests' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'indictrans.trunk.tests' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'indictrans.trunk.tests' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'indictrans.trunk.tests' to be distributed and are
#               already explicitly excluding 'indictrans.trunk.tests' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying indictrans\_decode\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\beamsearch.c -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\beamsearch.pyx -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\viterbi.c -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_decode\viterbi.pyx -> build\lib.win-amd64-cpython-311\indictrans\_decode
#       copying indictrans\_utils\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\ctranxn.c -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\ctranxn.pyx -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\one_hot_encoder.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\script_normalizer.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\sparseadd.c -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\sparseadd.pyx -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\_utils\wx.py -> build\lib.win-amd64-cpython-311\indictrans\_utils
#       copying indictrans\mappings\punkt.map -> build\lib.win-amd64-cpython-311\indictrans\mappings
#       copying indictrans\mappings\urdu_urdu.map -> build\lib.win-amd64-cpython-311\indictrans\mappings
#       copying indictrans\models\ben-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-eng
#       copying indictrans\models\ben-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-guj
#       copying indictrans\models\ben-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-hin
#       copying indictrans\models\ben-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-kan
#       copying indictrans\models\ben-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-mal
#       copying indictrans\models\ben-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-ori
#       copying indictrans\models\ben-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-pan
#       copying indictrans\models\ben-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tam
#       copying indictrans\models\ben-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-tel
#       copying indictrans\models\ben-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\ben-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\ben-urd
#       copying indictrans\models\eng-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ben
#       copying indictrans\models\eng-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-guj
#       copying indictrans\models\eng-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-hin
#       copying indictrans\models\eng-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-kan
#       copying indictrans\models\eng-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-mal
#       copying indictrans\models\eng-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-ori
#       copying indictrans\models\eng-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-pan
#       copying indictrans\models\eng-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tam
#       copying indictrans\models\eng-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-tel
#       copying indictrans\models\eng-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\eng-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\eng-urd
#       copying indictrans\models\guj-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ben
#       copying indictrans\models\guj-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-eng
#       copying indictrans\models\guj-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-hin
#       copying indictrans\models\guj-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-kan
#       copying indictrans\models\guj-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-mal
#       copying indictrans\models\guj-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\guj-ori
#       copying indictrans\models\guj-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\guj-pan
# ...
#       copying indictrans\models\tel-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ben
#       copying indictrans\models\tel-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-eng
#       copying indictrans\models\tel-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-guj
#       copying indictrans\models\tel-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-hin
#       copying indictrans\models\tel-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-kan
#       copying indictrans\models\tel-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-mal
#       copying indictrans\models\tel-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-ori
#       copying indictrans\models\tel-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-pan
#       copying indictrans\models\tel-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-tam
#       copying indictrans\models\tel-urd\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\tel-urd\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\tel-urd
#       copying indictrans\models\urd-ben\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-ben\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ben
#       copying indictrans\models\urd-eng\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-eng\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-eng
#       copying indictrans\models\urd-guj\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-guj\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-guj
#       copying indictrans\models\urd-hin\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-hin\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-hin
#       copying indictrans\models\urd-kan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-kan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-kan
#       copying indictrans\models\urd-mal\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-mal\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-mal
#       copying indictrans\models\urd-ori\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-ori\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-ori
#       copying indictrans\models\urd-pan\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-pan\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-pan
#       copying indictrans\models\urd-tam\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tam\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tam
#       copying indictrans\models\urd-tel\classes.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\coef.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_final.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_init.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\intercept_trans.npy -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\models\urd-tel\sparse.vec -> build\lib.win-amd64-cpython-311\indictrans\models\urd-tel
#       copying indictrans\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\ben_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\eng_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\guj_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\hin_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\hin_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\indic-test -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\kan_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\mal_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\ori_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\pan_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\pan_urd.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\tam_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\tel_eng.testpairs -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\tests\test_trans.py -> build\lib.win-amd64-cpython-311\indictrans\tests
#       copying indictrans\trunk\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\perceptron.py -> build\lib.win-amd64-cpython-311\indictrans\trunk
#       copying indictrans\trunk\tests\__init__.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\hin2rom.tnt -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       copying indictrans\trunk\tests\test_trunk.py -> build\lib.win-amd64-cpython-311\indictrans\trunk\tests
#       running build_ext
#       building 'indictrans._decode.beamsearch' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for indictrans
# ERROR: Could not build wheels for indictrans, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from indictrans import Transliterator
import time, math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from indictrans import Transliterator
#       2 import time, math
#
# File d:\koding\codes\Machine Learning\ICTC\Notebooks\indictrans\__init__.py:9
#       6 import codecs
#       7 import argparse
# ----> 9 from ._utils import UrduNormalizer, WX
#      10 from .transliterator import Transliterator
#      12 __all__ = ['Transliterator', 'UrduNormalizer', 'WX']
#
# File d:\koding\codes\Machine Learning\ICTC\Notebooks\indictrans\_utils\__init__.py:6
#       1 #!/usr/bin/env python
#       2
#       3 # Copyright (C) 2015 Irshad Ahmad Bhat
#       5 from .wx import WX
# ----> 6 from .ctranxn import count_tranxn
#       7 from .sparseadd import sparse_add
#       8 from .one_hot_encoder import OneHotEncoder
#
# ModuleNotFoundError: No module named 'indictrans._utils.ctranxn'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB # best
from sklearn.linear_model import LogisticRegression
import numpy as np
import random
import os
from tqdm import tqdm

# %%
df_text="कांग्रेस पार्टी अध्यक्ष सोनिया गांधी, तमिलनाडु की मुख्यमंत्री जयललिता और रिज़र्व बैंक के गवर्नर रघुराम राजन के बीच एक समानता है. ये सभी अलग-अलग कारणों से भारतीय जनता पार्टी के राज्यसभा सांसद सुब्रमण्यम स्वामी के निशाने पर हैं. उनके जयललिता और सोनिया गांधी के पीछे पड़ने का कारण कथित भ्रष्टाचार है."

# %%
df_test = pd.read_csv('icdc\english translation\english-translation.csv')
df = pd.read_csv(r'icdc\train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ben     1700 non-null   object
#  1   guj     1700 non-null   object
#  2   hin     1700 non-null   object
#  3   kan     1700 non-null   object
#  4   mal     1700 non-null   object
#  5   ori     1700 non-null   object
#  6   pan     1700 non-null   object
#  7   tam     1700 non-null   object
#  8   tel     1700 non-null   object
#  9   urd     1700 non-null   object
#  10  eng     1700 non-null   object
# dtypes: object(11)
# memory usage: 146.2+ KB

# %%
LANGS = ['ben', 'hin', 'pan', 'tam', 'tel']

# %%
dfs=[]
for i,col_name in enumerate(df.columns):
    if col_name in LANGS:
        df2=pd.DataFrame({'Comment':df[col_name],'Language_Index': LANGS.index(col_name), 'Language': col_name})
        dfs.append(df2)

result_df = pd.concat(dfs, ignore_index=True)   
print(len(dfs)) 

X=result_df['Comment']
Y=result_df['Language_Index']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=26)
# Out:
# 5

# %%
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error

# %%
vectorizer = TfidfVectorizer()
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# %%
lr_classifier = LogisticRegression(max_iter=300)
lr_classifier.fit(X_train_vect, y_train)
pred_lr = lr_classifier.predict(X_test_vect)

print("Accuracy:", accuracy_score(y_test, lr_classifier.predict(X_test_vect)))
# Out:
# Accuracy: 0.981764705882353

# %%
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_vect, y_train)
pred_nb = nb_classifier.predict(X_test_vect)
print("Accuracy:", accuracy_score(y_test, pred_nb))
# Out:
# Accuracy: 0.9905882352941177

# %%
# NORMALIZE and MAKE between 0 and 1
def prob(arr:np.ndarray, gap_adjuster:int=3)->np.ndarray:
    if len(arr.shape) == 1:
        arr = (arr-arr.min())/(arr.max()-arr.min())
        if gap_adjuster!=1: arr = arr**gap_adjuster
        return arr/arr.sum()
    else:
        arr = (arr-arr.min(axis=1).reshape(-1, 1))/(arr.max(axis=1)-arr.min(axis=1)).reshape(-1, 1)
        if gap_adjuster!=1: arr = arr**gap_adjuster
        return arr/arr.sum(axis=1).reshape(-1, 1)
    

def emsemble_infer_v2(texts:str|list[str], printable=False):
    if isinstance(texts, str): texts = [texts]
    output = (
        prob(lr_classifier.predict_proba(vectorizer.transform(texts)), gap_adjuster=1) + 
        prob(nb_classifier.predict_proba(vectorizer.transform(texts)), gap_adjuster=1) #+
    ).argmax(axis=1)
    if printable:
        return [LANGS[i] for i in output.tolist()]
    else:
        return output
    
pred_emsemble_v2 = []
for i in tqdm(range(0, len(X_test), 64)):
    pred_emsemble_v2.append(emsemble_infer_v2(X_test[i:i+64]))

pred_emsemble_v2 = np.concatenate(pred_emsemble_v2, axis = 0)

print("F1 score: ", f1_score(y_test, pred_emsemble_v2, average='weighted'))
print("Accuracy: ", accuracy_score(y_test, pred_emsemble_v2))
print("MSE: ", mean_squared_error(y_test, pred_emsemble_v2))
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 152.80it/s]
# F1 score:  0.9894222540839781
# Accuracy:  0.9894117647058823
# MSE:  0.05411764705882353

# %%
df_translitration=df_test['text'].tolist()

# %%
pred_emsemble_v2 = []
for i in tqdm(range(0, len(df_translitration), 64)):
    pred_emsemble_v2.append(emsemble_infer_v2(df_translitration[i:i+64]))

pred_emsemble_v2 = np.concatenate(pred_emsemble_v2, axis = 0)
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 118.50it/s]

# %%
df_test
# Out:
#                                                   text
# 0                            seta to khubi bhaal have!
# 1    m mase kono ullekhayogya tapapravaher dasha an...
# 2                     ei sabkatai darun lagno shunate.
# 3    tar prabandh, ya ki na tar agami bayer ekati u...
# 4    bartaman mammla, njity taar ekhtiar parityag k...
# ..                                                 ...
# 795  1997lo sanyo "pioessiepi" palimar tantelu chip...
# 796  nenu i pradeshal gurinchi ippatike chala chadi...
# 797    gurtunda, edadi kindat me kolig biknu kalcharu.
# 798  bharatvaesha gopp vaividhya-vyatyasabharit bhumi.
# 799                             repe ambedkar jayanti!
#
# [800 rows x 1 columns]

# %%
LANGS
# Out:
# ['ben', 'hin', 'pan', 'tam', 'tel']

# %%
# Mapping of integers to labels
label_mapping = {
    idx:name for idx, name in enumerate(LANGS)
}

# Assuming `output` is the concatenated list of integers
labels = [label_mapping[i] for i in pred_emsemble_v2 ]

print(labels)
# Out:
# ['ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'ben', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'hin', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'hin', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'pan', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 'tam', 't ...

# %%
len(labels)
# Out:
# 800

# %%
df_test['Language'] = labels

# %%
df_test['Language_index']=pred_emsemble_v2

# %%
df_test
# Out:
#                                                   text Language  \
# 0                            seta to khubi bhaal have!      ben
# 1    m mase kono ullekhayogya tapapravaher dasha an...      ben
# 2                     ei sabkatai darun lagno shunate.      ben
# 3    tar prabandh, ya ki na tar agami bayer ekati u...      ben
# 4    bartaman mammla, njity taar ekhtiar parityag k...      ben
# ..                                                 ...      ...
# 795  1997lo sanyo "pioessiepi" palimar tantelu chip...      tel
# 796  nenu i pradeshal gurinchi ippatike chala chadi...      tel
# 797    gurtunda, edadi kindat me kolig biknu kalcharu.      tel
# 798  bharatvaesha gopp vaividhya-vyatyasabharit bhumi.      tel
# 799                             repe ambedkar jayanti!      tel
#
#      Language_index
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 795               4
# 796               4
# 797               4
# 798               4
# 799               4
#
# [800 rows x 3 columns]

# %%
from tqdm import tqdm
trans_lan = []
for i in tqdm(range(len(df_test))):
    req_text = df_test.loc[i, "text"]
    language_code = df_test.loc[i, "Language"]
    trn = Transliterator(source='eng', target=language_code, build_lookup=True)
    eng = trn.transform(req_text)
    trans_lan.append(eng)
    print(eng)

# %%
df_test['trans_lan'] = trans_lan

# %%
df_test.iloc[200]
# Out:
# text              kuch padyon main rahasyodghatan kaa tarika bat...
# Language                                                        hin
# Language_index                                                    1
# trans_lan         कुछ पद्यों में रहस्योदघटन का तारीका बताया गया ...
# Name: 200, dtype: object

# %%
import pandas as pd
import numpy as np
import random
import os
from tqdm import tqdm

# %%
df_test = pd.read_csv('icdc/english translation/english-translation_post.csv')

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
tokenizer = AutoTokenizer.from_pretrained("Translation_draco", local_files_only=True)

model = AutoModelForSeq2SeqLM.from_pretrained("Translation_draco", local_files_only=True)

# %%
def translate_text(text):
    input_ids = tokenizer(text, return_tensors="pt").input_ids

    outputs = model.generate(input_ids, max_length = 512)

    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return translated_text

# %%
from tqdm import tqdm
test_text = df_test['text']

final_text = []

for i in tqdm(range(800)):  # Loop through the first 800 rows
    input_text = df_test['trans_lan'][i]
    translated_text = translate_text(input_text)
    final_text.append(translated_text)
# Out:
# 100%|██████████| 800/800 [19:22<00:00,  1.45s/it]

# %%
import pickle
with open('icdc/english translation/final_text.pkl', 'wb') as f: pickle.dump(final_text, f)

# %%
df_test['eng'] = final_text

# %%
df_test.to_csv('icdc/english translation/final_text.csv')

# %%
df_sub = df_test.drop('Language', axis=1)

# %%
df_sub = df_sub.drop('Unnamed: 0', axis=1)
df_sub = df_sub.drop('Language_index', axis=1)
df_sub = df_sub.drop('trans_lan', axis=1)
df_sub = df_sub.drop('final_text', axis=1)

# %%
df_sub.to_csv('icdc/english translation/english-translation-submission.csv', index=False)
